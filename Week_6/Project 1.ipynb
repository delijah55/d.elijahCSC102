# %%
import pandas as pd

df1 = pd.read_csv("C:\\Users\\USER PC\\Documents\\d.elijahCSC102\\Week_6\\Datasets\\Top_Apps.csv")
df2 = pd.read_csv("C:\\Users\\USER PC\\Documents\\d.elijahCSC102\\Week_6\Datasets\\BTC_DATA.csv")
df3 = pd.read_csv("C:\\Users\\USER PC\\Documents\\d.elijahCSC102\\Week_6\\Datasets\\dataset.csv")



print("Top Apps dataset:")
print(df1.head(7))
print("\nCryptocurrency Predict AI V3 dataset:")
print(df2.head(7))
print("\nProgramming Languages and File Format Detection dataset:")
print(df3.head(7))

df
# Out:
# Top Apps dataset:
#    Unnamed: 0                          App Name  \
# 0           1              Google Play services
# 1           2                           YouTube
# 2           3                            Google
# 3           4  Google Maps - Navigate & Explore
# 4           5             Google Text-to-Speech
# 5           6      Google Chrome: Fast & Secure
# 6           7                             Gmail
#
#                                     App Id                 Category  \
# 0                   com.google.android.gms                    Tools
# 1               com.google.android.youtube  Video Players & Editors
# 2  com.google.android.googlequicksearchbox                    Tools
# 3             com.google.android.apps.maps           Travel & Local
# 4                   com.google.android.tts                    Tools
# 5                       com.android.chrome            Communication
# 6                    com.google.android.gm            Communication
#
# ...
